# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('sowsang.csv')
df.head()
# Out:
#    idx                      유저                      챗봇
# 0    1       붕대 안 썼으면 환불 가능해요?  네, 붕대 안 쓰셨으면 환불 가능합니다.
# 1    2      붕대 안 썼는데 환불 가능한가요?  네, 붕대 안 쓰셨다면 환불 가능합니다.
# 2    3                     NaN                     NaN
# 3    4  붕대 안 썼는데 환불해 주실 수 있어요?        네, 환불해드릴 수 있습니다.
# 4    5                     NaN                     NaN

# %%
df = df[~df['챗봇'].isna()]
df.head()
# Out:
#    idx                          유저                      챗봇
# 0    1           붕대 안 썼으면 환불 가능해요?  네, 붕대 안 쓰셨으면 환불 가능합니다.
# 1    2          붕대 안 썼는데 환불 가능한가요?  네, 붕대 안 쓰셨다면 환불 가능합니다.
# 3    4      붕대 안 썼는데 환불해 주실 수 있어요?        네, 환불해드릴 수 있습니다.
# 5    6      붕대 안 쓸 건데 환불해 주실 수 있죠?      그럼요, 환불해드릴 수 있습니다.
# 6    7  붕대 안 쓸 건데 환불해 주실 수 있는 건가요?       그럼요, 환불해드릴 수 있어요.

# %%
df.loc[0,'유저']
# Out:
# '붕대 안 썼으면 환불 가능해요?'

# %%
model.encode(df.loc[0,'유저'])
# Out:
# array([-6.63721442e-01, -1.78273901e-01,  3.02568704e-01,  2.19591949e-02,
#         2.65469663e-02, -2.00304136e-01,  3.83983523e-01, -3.21950078e-01,
#        -2.17022285e-01,  6.37930408e-02, -2.11964175e-01, -4.26421672e-01,
#        -1.85272068e-01,  2.46641174e-01, -2.39650726e-01, -9.11189079e-01,
#         2.98626751e-01,  5.94110906e-01,  2.75475174e-01, -8.01393569e-01,
#        -5.13518155e-01, -2.73083955e-01, -1.87997431e-01,  6.95193708e-01,
#        -4.08220887e-01, -4.57598507e-01, -8.39286298e-02, -2.29880005e-01,
#        -1.34777208e-03, -2.41702303e-01,  2.54991502e-01,  3.83704677e-02,
#         8.88541043e-02,  2.68597662e-01,  2.65842527e-01,  2.84220546e-01,
#        -7.25837886e-01,  6.11395128e-02, -1.47951901e-01,  5.66080630e-01,
#        -3.94000918e-01, -1.25132084e-01, -1.44745678e-01,  2.66990010e-02,
#         5.19218206e-01,  4.66670841e-02, -1.01912908e-01,  2.62312195e-03,
#        -1.71893522e-01, -5.75512588e-01, -3.48637491e-01, -1.12067655e-01,
#        -1.00123554e-01,  2.34070867e-01,  7.51910210e-02,  4.94926751e-01,
#         4.80165690e-01, -3.61464500e-01,  2.92630792e-01, -2.97314048e-01,
#        -1.01597896e-02, -5.86292803e-01,  6.82913810e-02,  2.97735006e-01,
#         6.37417734e-02,  4.54285070e-02,  1.83765873e-01, -1.42113745e-01,
#        -6.02094233e-01,  4.10257339e-01, -1.37052998e-01,  1.72637984e-01,
#         3.80265154e-02, -1.09964065e-01,  6.01048052e-01,  1.00602293e-02,
#        -3.30223292e-01, -1.42680168e-01, -1.71799183e-01, -8.34075928e-01,
#         3.71631533e-01, -2.18401894e-01,  2.61215419e-01,  3.62609141e-02,
py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['embedding'] = df['유저'].map(lambda x: list(model.encode(x)))
#    idx                          유저                      챗봇  \
# 0    1           붕대 안 썼으면 환불 가능해요?  네, 붕대 안 쓰셨으면 환불 가능합니다.
# 1    2          붕대 안 썼는데 환불 가능한가요?  네, 붕대 안 쓰셨다면 환불 가능합니다.
# 3    4      붕대 안 썼는데 환불해 주실 수 있어요?        네, 환불해드릴 수 있습니다.
# 5    6      붕대 안 쓸 건데 환불해 주실 수 있죠?      그럼요, 환불해드릴 수 있습니다.
# 6    7  붕대 안 쓸 건데 환불해 주실 수 있는 건가요?       그럼요, 환불해드릴 수 있어요.
#
#                                            embedding
# 0  [-0.66372144, -0.1782739, 0.3025687, 0.0219591...
# 1  [-0.9515985, -0.110164516, 0.34898937, 0.08312...
# 3  [-0.7817196, -0.13718405, 0.36344633, 0.117742...
# 5  [-0.8405528, -0.036251254, 0.3505641, 0.242614...
# 6  [-1.015931, 0.023863796, 0.33913296, 0.0559348...

# %%
df.to_csv('sowsang.csv',index=False)

# %%
text='붕대 안 썼으면 환불 가능해요?'
embedding = model.encode(text)

# %%
df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding],[x]).squeeze())
df.head()
# Out:
# C:\Users\nextop\AppData\Local\Temp\ipykernel_12044\2234608100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding],[x]).squeeze())
#    idx                          유저                      챗봇  \
# 0    1           붕대 안 썼으면 환불 가능해요?  네, 붕대 안 쓰셨으면 환불 가능합니다.
# 1    2          붕대 안 썼는데 환불 가능한가요?  네, 붕대 안 쓰셨다면 환불 가능합니다.
# 3    4      붕대 안 썼는데 환불해 주실 수 있어요?        네, 환불해드릴 수 있습니다.
# 5    6      붕대 안 쓸 건데 환불해 주실 수 있죠?      그럼요, 환불해드릴 수 있습니다.
# 6    7  붕대 안 쓸 건데 환불해 주실 수 있는 건가요?       그럼요, 환불해드릴 수 있어요.
#
#                                            embedding  distance
# 0  [-0.66372144, -0.1782739, 0.3025687, 0.0219591...  1.000000
# 1  [-0.9515985, -0.110164516, 0.34898937, 0.08312...  0.961917
# 3  [-0.7817196, -0.13718405, 0.36344633, 0.117742...  0.937429
# 5  [-0.8405528, -0.036251254, 0.3505641, 0.242614...  0.876187
# 6  [-1.015931, 0.023863796, 0.33913296, 0.0559348...  0.877624

# %%
answer = df.loc[df['distance'].idxmax()]

print('구분',answer['구분'])
print('유사한 질문',answer['유저'])
print('챗봇 답변', answer['챗봇'])
print('유사도',answer['distance'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구분'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
#       1 answer = df.loc[df['distance'].idxmax()]
# ----> 3 print('구분',answer['구분'])
#       4 print('유사한 질문',answer['유저'])
#       5 print('챗봇 답변', answer['챗봇'])
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\envs\chatbot\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '구분'
